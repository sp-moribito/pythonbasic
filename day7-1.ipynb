# %%
# 필요한 모듈 설치
#!pip install pillow : 사진 관련 모듈 설치
#!pip install requests : 인터넷 연결 관련 모듈 설치

# !pip install pillow
# !pip install requests

# %%
import matplotlib.pyplot as plt # 그림관련
import matplotlib.image as mpimg # 사진관련

#생략 가능 : 브라우저 상에서의 그림 표현
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img=mpimg.imread('face1.jpg') #사진 가져오기(동일한 폴더에 있기 때문에 파일명만 가져옴)

plt.figure(figsize=(10,8)) #가져올 사진의 사이즈
plt.imshow(img)
plt.show()

# %%
#유명인 얼굴과 얼마나 비슷한지 검색

import requests # 인터넷 연결

client_id = "d3a5T02tTzMKMU88PzQt" # 네이버 개발자센터 ID
client_secret = "UkuNDrV1MU" # 네이버 개발자센터 PW

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}

response=requests.post(url,files=files,headers=headers)

# %%
import json #json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed,indent=4,sort_keys=False,ensure_ascii=False))

# 사진 한 장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.283918
#             }
#         }
#     ]
# }

# %%
# 얼굴 인식, 나이 예측, 감정 분석

import requests # 인터넷 연결

client_id = "d3a5T02tTzMKMU88PzQt"
client_secret = "UkuNDrV1MU"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}

response=requests.post(url,files=files,headers=headers)

# %%
import json #json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed,indent=4,sort_keys=False,ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
# ...

# %%
#가족 사진 분석

import requests # 인터넷 연결

client_id = "d3a5T02tTzMKMU88PzQt"
client_secret = "UkuNDrV1MU"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}

response=requests.post(url,files=files,headers=headers)

# %%
import json #json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed,indent=4,sort_keys=False,ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
# ...

# %%
# 기본 문법 학습 : dict형과 json에 대해서
# 1) dict형

dict = {
    'Name':'pinkwink',
    'Age':'None',
    'Class':['beginner','blog']
}
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('Age','nothing') #'Age'가 있으면 출력하고, 없으면 'Nothing'을 출력하라
# Out:
# 'None'

# %%
dict.get('Room','nothing')
# Out:
# 'nothing'

# %%
# 2) json
# json = Java Script Object Notation

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'date':'2019-03-01','log':True},
        {'date':'2019-03-02','log':False},
    ]
}

# %%
import json
json_test=json.dumps(customer,indent=4, ensure_ascii=False) #ensure_ascii는 글자 깨짐 막아줌
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
# 사진 위에 개인 정보 표시하기

# 위의 face1 분석 코드 그대로 가져옴

import requests # 인터넷 연결

client_id = "d3a5T02tTzMKMU88PzQt"
client_secret = "UkuNDrV1MU"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}

response=requests.post(url,files=files,headers=headers)

import json #json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed,indent=4,sort_keys=False,ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
# ...

# %%
img=mpimg.imread('face1.jpg') 

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(response)
# Out:
# <Response [200]>

# %%
parsed['faces']
# Out:
# [{'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#   'landmark': {'leftEye': {'x': 298, 'y': 124},
#    'rightEye': {'x': 350, 'y': 129},
#    'nose': {'x': 320, 'y': 157},
#    'leftMouth': {'x': 297, 'y': 182},
#    'rightMouth': {'x': 343, 'y': 186}},
#   'gender': {'value': 'male', 'confidence': 0.999998},
#   'age': {'value': '30~34', 'confidence': 0.441697},
#   'emotion': {'value': 'neutral', 'confidence': 1.0},
#   'pose': {'value': 'frontal_face', 'confidence': 0.991977}}]

# %%
parsed['faces'][0] # 1명밖에 없어서 의미는 없다.
# Out:
# {'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#  'landmark': {'leftEye': {'x': 298, 'y': 124},
#   'rightEye': {'x': 350, 'y': 129},
#   'nose': {'x': 320, 'y': 157},
#   'leftMouth': {'x': 297, 'y': 182},
#   'rightMouth': {'x': 343, 'y': 186}},
#  'gender': {'value': 'male', 'confidence': 0.999998},
#  'age': {'value': '30~34', 'confidence': 0.441697},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.991977}}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999998}

# %%
parsed['faces'][0]['roi'] # 얼굴의 위치값
# Out:
# {'x': 272, 'y': 98, 'width': 113, 'height': 113}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '30~34', 'confidence': 0.441697}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
print(x,y,w,h)
# Out:
# 272 98 113 113

# %%
gender,gen_confi = parsed['faces'][0]['gender'].values()
print(gender,gen_confi)
# Out:
# male 0.999998

# %%
emotion,emo_confi=parsed['faces'][0]['emotion'].values()
print(emotion,emo_confi)
# Out:
# neutral 1.0

# %%
age,age_confi=parsed['faces'][0]['age'].values()
print(age,age_confi)
# Out:
# 30~34 0.441697

# %%
annotation=gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " : " + str(age_confi)
print(annotation)
# Out:
# male : 0.999998
# neutral : 1.0
# 30~34 : 0.441697

# %%
import matplotlib.patches as patches

img=mpimg.imread('face1.jpg')

fig,ax=plt.subplots(figsize=(10,10)) #액자에 사진올리기
ax.imshow(img)

rect_face=patches.Rectangle((x,y),w,h,linewidth=5,edgecolor='r',facecolor='none')
#위에서 설정한 얼굴의 위치값이 들어감

ax.add_patch(rect_face) #설정한 값을 사진에 적용

plt.text(10,400,annotation,wrap=True,fontsize=17,color='white')
plt.show()

# %%
#이번에는 여러 얼굴로 해보자
img=mpimg.imread('face2.jpg') 

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "d3a5T02tTzMKMU88PzQt"
client_secret = "UkuNDrV1MU"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}

response=requests.post(url,files=files,headers=headers)

import json #json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed,indent=4,sort_keys=False,ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
# ...

# %%
# 'facecount : 4'를 확인하자

import matplotlib.patches as patches

img=mpimg.imread('face2.jpg') 

fig,ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in parsed['faces']:
    x,y,w,h = each['roi'].values() #parsed['faces'][i]는 each 값으로 이미 들어와있다.
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi=each['emotion'].values()
    age,age_confi=each['age'].values()
    
    rect_face=patches.Rectangle((x,y),w,h,linewidth=5,edgecolor='r',facecolor='none')

    ax.add_patch(rect_face)
    
    annotation=gender + " : " + str(round(gen_confi*100,2)) + '%' + '\n' + emotion + " : " + str(round(emo_confi*100,2)) + '%' + '\n' + age + " : " + str(round(age_confi*100,2))+'%'
    plt.text(x-20,y-10,annotation,wrap=True,fontsize=8,color='red')

plt.show()
